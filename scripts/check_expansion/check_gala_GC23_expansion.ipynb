# %%
# %pylab inline
import sys
sys.path.append('../../MW-LMC-SCF/code')
from read_coefficients import load_scf_coefficients
plt.style.use('~/matplotlib.mplstyle')
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
import gala.potential as gp
import k3d
import bfe
import astropy.units as u

# %%
gp.scf.SCFInterpolatedPotential

# %%
# Load Expansions 

def load_gc23_exp(mwlmc, n_init, n_final, host=False, sat=False,): 
    path_to_exp = "../../data/expansion/{}_1e7/".format(mwlmc)
    host_path = "BFE_{}_grav_MO3_simple_1e7_COM_n20_l20_debris_test_host_snap_".format(mwlmc)
    sat_path = "BFE_{}_grav_MO3_simple_1e7_COM_n20_l20_debris_test_sat_snap_".format(mwlmc)
    
    nsnaps = n_final - n_init
    
    coefficients = []
    exp_length = []
    exp_param = []
    com = []
    
    if host == True:
        host_coeff = np.zeros((nsnaps, 3, 21, 21, 21))
        host_rcom = np.zeros((nsnaps, 3))
        for i in range(n_init, n_final):
            host_coeff[i-n_init], exp_host_length, exp_host_params, host_rcom[i-n_init] = bfe.ios.read_coefficients(path_to_exp
                                                                                                       + host_path
                                                                                                       + "{:03d}".format(i))
        coefficients.append(host_coeff)
        exp_length.append(exp_host_length)
        exp_param.append(exp_host_params)
        com.append(host_rcom)
        
    if sat == True:
        sat_coeff = np.zeros((nsnaps, 3, 21, 21, 21))
        sat_rcom = np.zeros((nsnaps, 3))
        
        for i in range(n_init, n_final):
            sat_coeff[i-n_init], exp_sat_length, exp_sat_params, sat_rcom[i-n_init] = bfe.ios.read_coefficients(path_to_exp
                                                                                                       + sat_path
                                                                                                       + "{:03d}".format(i))
        coefficients.append(sat_coeff)
        exp_length.append(exp_sat_length)
        exp_param.append(exp_sat_params)
        com.append(sat_rcom)
        
    
        
    return coefficients, exp_length, exp_param, com

# %%
mwlmc5_coeff, mwmlc5_exp_length, mwlmc5_exp_params, mwlmc5_rcom = load_gc23_exp('MWLMC5', 0, 400, True, True)
# Out:
# <KeysViewHDF5 ['G', 'Snlm', 'Tnlm', 'lmax', 'mmax', 'nmax', 'pmass', 'rcom', 'rs', 'var_STnlm', 'var_Snlm', 'var_Tnlm']>
# * Loading coefficients
# <KeysViewHDF5 ['G', 'Snlm', 'Tnlm', 'lmax', 'mmax', 'nmax', 'pmass', 'rcom', 'rs', 'var_STnlm', 'var_Snlm', 'var_Tnlm']>
# * Loading coefficients
# <KeysViewHDF5 ['G', 'Snlm', 'Tnlm', 'lmax', 'mmax', 'nmax', 'pmass', 'rcom', 'rs', 'var_STnlm', 'var_Snlm', 'var_Tnlm']>
# * Loading coefficients
# <KeysViewHDF5 ['G', 'Snlm', 'Tnlm', 'lmax', 'mmax', 'nmax', 'pmass', 'rcom', 'rs', 'var_STnlm', 'var_Snlm', 'var_Tnlm']>
# * Loading coefficients
# <KeysViewHDF5 ['G', 'Snlm', 'Tnlm', 'lmax', 'mmax', 'nmax', 'pmass', 'rcom', 'rs', 'var_STnlm', 'var_Snlm', 'var_Tnlm']>
# * Loading coefficients
# <KeysViewHDF5 ['G', 'Snlm', 'Tnlm', 'lmax', 'mmax', 'nmax', 'pmass', 'rcom', 'rs', 'var_STnlm', 'var_Snlm', 'var_Tnlm']>
# * Loading coefficients
# ...

# %%
## Implement smoothening
## Smatrix = mwlmc_bfe.coefficients_smoothing.reshape_matrix(S, 20, 20, 20)
## Tmatrix = mwlmc_bfe.coefficients_smoothing.reshape_matrix(T, 20, 20, 20)

# %%
## Visualize fields

# %%
mwlmc5_host_rs = mwlmc5_exp_params[0][0]
mwlmc5_sat_rs = mwlmc5_exp_params[1][0]

# %%
mwlmc5_host_rs
# Out:
# array(40.85)

# %%
gp.SCFPotential

# %%
gp.scf.SCFInterpolatedPotential?

# %%
pot_scf = gp.scf.SCFInterpolatedPotential(m=1E10*u.Msun, r_s=40.85*u.kpc, tj = np.arange(0, 8, 0.02)*u.Gyr,
                          Sjnlm=mwlmc5_coeff[0][:,0,:,:,:], Tjnlm=mwlmc5_coeff[0][:,1,:,:,:], 
                          com_xj = mwlmc5_rcom[0]*u.kpc, com_vj=np.zeros((400, 3))*u.km/u.s,
                          units=[u.kpc, u.Gyr, u.Msun, u.radian])

# %%
pot_scf.density

# %%
pot_slice = pot_scf.density([20, 20, 20], t=0.0)
print(pot_slice)
# Out:
# [672617.15582935] solMass / kpc3

# %%
pot_slice = pot_scf.density([20, 20, 20], t=4.0)
print(pot_slice)
# Out:
# [683401.02736168] solMass / kpc3

# %%
pot_scf.plot_contours((0, grid, grid), t=0.0)

# %%
pot_scf.plot_contours((0, grid, grid), t=3.0)

# %%
pot_scf.plot_contours()

# %%
grid = np.linspace(-120, 120, 128)
fig, axes = plt.subplots(2, 2, figsize=(10, 10),
                         sharex=True, sharey=True)
_ = pot_scf.plot_contours((grid, grid, 0), ax=axes[0][0], t=0.0)
a
axes[0][0].set_xlabel('$x$')
axes[0][0].set_ylabel('$y$')

_ = pot_scf.plot_contours((grid, 0, grid), ax=axes[0][1], t=0.0)
axes[0][1].set_xlabel('$x$')
axes[0][1].set_ylabel('$z$')


_ = pot_scf.plot_density_contours((grid, grid, 0), ax=axes[1][0], t=0.0)

axes[1][0].set_xlabel('$x$')
axes[1][0].set_ylabel('$y$')

_ = pot_scf.plot_density_contours((grid, 0, grid), ax=axes[1][1], t=0.0)
axes[1][1].set_xlabel('$x$')
axes[1][1].set_ylabel('$z$')

# %%
Svarmatrix = mwlmc_bfe.coefficients_smoothing.reshape_matrix(Svar, 20, 20, 20)
Tvarmatrix = mwlmc_bfe.coefficients_smoothing.reshape_matrix(Tvar, 20, 20, 20)
STvarmatrix = mwlmc_bfe.coefficients_smoothing.reshape_matrix(STvar, 20, 20, 20)

# %%
fig, ax = subplots(1, 2, figsize=(12, 5))
density_slab(fig, ax[0], Smatrix, Tmatrix, vmin=-7, vmax=3, plane='yz')
density_slab(fig, ax[1], Smatrix, Tmatrix, vmin=-1, vmax=1, plane='yz', delta=1)

# %%
imshow(np.log10(np.abs(Smatrix[:,:,0].T)), origin='lower')
colorbar()

# %%
mp = 1.843281E-6

# %%
Ssmoth, Tsmoth, N_smoth, snout = mwlmc_bfe.coefficients_smoothing.smooth_coeff_matrix(Smatrix, Tmatrix, Svarmatrix, 
                                                                                      Tvarmatrix, STvarmatrix, mass=mp, 
                                                                                     nmax=20, lmax=20, mmax=20, sn=3, sn_out=1)
# Out:
# ../../MW-LMC-SCF/code/coefficients_smoothing.py:100: RuntimeWarning: invalid value encountered in double_scalars
#   bt = 1 / (1 + (varT/T**2))

# %%
fig, ax = subplots(1, 2, figsize=(12, 5))
density_slab(fig, ax[0], Ssmoth, Tsmoth, vmin=-7, vmax=3, plane='yz')
density_slab(fig, ax[1], Ssmoth, Tsmoth, vmin=-1, vmax=1, plane='yz', delta=1)

# %%
imshow(np.log10(np.abs(Ssmoth[:,:,0].T)), origin='lower')
colorbar()
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.

# %%
N_smoth
# Out:
# 666
